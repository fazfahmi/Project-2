# %% [markdown]
# # 1. Perkenalan

# %% [markdown]
# **Mileston 2**
#
# Nama        : Fahmi
#
# Batch       : RMT-34
#
# Objective   : Notebook ini merupakan modul untuk menguji unseen data/model inference dari model yang sebelumnya saya buat, yakni classification untuk menentukan customer akan melakukan pembelian (purchase) atau tidak.

# %% [markdown]
# # 2. Import Libraries

# %% [markdown]
# Selanjutnya, saya mengimport pustaka yang diperlukan sebagai berikut.

# %%
# Libraries
import pandas as pd
import joblib

# %% [markdown]
# Pustaka selesai di-import.

# %% [markdown]
# # 3. Model Load

# %% [markdown]
# Berikutnya, saya muat model terbaik yang sebelumnya disimpan.

# %%
# load model
model = joblib.load('my_model.pkl')
model
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('num',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer()),
#                                                                   ('scaler',
#                                                                    MinMaxScaler())]),
#                                                   ['Age', 'AnnualIncome',
#                                                    'NumberOfPurchases',
#                                                    'TimeSpentOnWebsite',
#                                                    'DiscountsAvailed']),
#                                                  ('cat',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(strategy='most_frequent')),
# ...

# %% [markdown]
# Model sudah siap dipakai.

# %% [markdown]
# # 4. Unseen Data/Data Inference

# %% [markdown]
# Di sini, saya mendefinisikan unseen data yang tidak ada di dalam dataset `P1G6_Set_1_fahmi.csv` untuk digunakan sebagai bahan pengujian sebagai berikut.

# %%
# load data
data = {
    'Age': [43],
    'Gender': [1],
    'AnnualIncome': [40000],
    'NumberOfPurchases': [9],
    'ProductCategory': [1],
    'TimeSpentOnWebsite': [35],
    'LoyaltyProgram': [1],
    'DiscountsAvailed': [3]}

# Ubah data ke DataFrame
data_inf = pd.DataFrame(data)

# Cek
data_inf
# Out:
#    Age  Gender  AnnualIncome  NumberOfPurchases  ProductCategory  \
# 0   43       1         40000                  9                1
#
#    TimeSpentOnWebsite  LoyaltyProgram  DiscountsAvailed
# 0                  35               1                 3

# %% [markdown]
# # 5. Prediction

# %% [markdown]
# Data inference kemudian saya training dengan model sekaligus menentukan prediksinya.

# %%
# melatih data dan membuat prediksi
predictions = model.predict(data_inf)

# %%
predictions
# Out:
# array([1], dtype=int64)

# %% [markdown]
# Walhasil, customer dengan data inference tersebut diprediksi akan melakukan pembelian/purchase. Itu ditunjukkan dengan value = 1 di atas.

# %% [markdown]
# Dengan begini, saya menilai bahwa model ini siap digunakan ke depannya untuk memprediksi apakah pelanggan tertentu akan melakukan pembelian atau tidak.
